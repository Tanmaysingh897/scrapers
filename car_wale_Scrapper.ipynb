# %%
import csv
import urllib
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
import time

# %%
brands=["Mahindra","Tata","Toyota","Skoda","Maruti","hyundai","Volkswagen","Ford"]
final=[]
for brand in brands:
    
    name_url="https://www.cardekho.com/used-"+brand+"+cars+in+bangalore"
    driver = webdriver.Chrome(executable_path="C:\\Users\\n\\.wdm\\drivers\\chromedriver\\win32\\85.0.4183.87\\chromedriver")
    print ("Requesting URL: " + name_url)
    driver.get(name_url) 
    time.sleep(1)   # URL requested in browser.
    elem = driver.find_element_by_tag_name("body")
    print ("Scrolling document upto bottom ...")
    no_of_pagedowns = 20
    while no_of_pagedowns:
        elem.send_keys(Keys.PAGE_DOWN)
        time.sleep(0.2)
        no_of_pagedowns-=1
    body = driver.find_element_by_tag_name("body").get_attribute("innerHTML")
    print("Closing Chrome ...") # No more usage needed.
    driver.quit()
    soupbody=BeautifulSoup(body,'html.parser')
    listi=[]
    href_container=soupbody.find_all('a',attrs={'href':re.compile("/used-car-details/used-")})
    for i in range(len(href_container)):
        listi.append([str(href_container[i])])
    links=[]
    for i in range(len(listi)):
        links.append(re.search('/used-car-details/used(.+?).htm', listi[i][0]).group(1))    
    print("row numbers:"+brand ,len(listi))
    total_data=[]
    for link in links:
        url="https://www.cardekho.com/used-car-details/used"+link+".htm"
        hdr = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.64 Safari/537.11',
         'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8',
         'Referer': 'https://cssspritegenerator.com',
         'Accept-Charset': 'ISO-8859-1,utf-8;q=0.7,*;q=0.3',
         'Accept-Encoding': 'none',
         'Accept-Language': 'en-US,en;q=0.8',
         'Connection': 'keep-alive'}
        page=urllib.request.Request(url,None,headers=hdr)
        response = urllib.request.urlopen(page)
        soupbody=BeautifulSoup(response,'html.parser')
        details=soupbody.find_all('div',{"class":"iconDetail"})
        name_container=soupbody.find_all('div',{"class":"vdp-head"})
        price_container=soupbody.find_all('span',{"class":"amount"})
        total_data.append(name_container[0].text)
        total_data.append(brand)
        total_data.append(price_container[0].text)
        for i in range(len(details)):
            total_data.append(details[i].text)
        final.append(list(total_data))
        total_data.clear()
    print("row_total",len(final))
# Out:
# Requesting URL: https://www.cardekho.com/used-Mahindra+cars+in+bangalore
# Scrolling document upto bottom ...
# Closing Chrome ...
# row numbers:Mahindra 53
# row_total 53
# Requesting URL: https://www.cardekho.com/used-Tata+cars+in+bangalore
# Scrolling document upto bottom ...
# Closing Chrome ...
# row numbers:Tata 38
# row_total 91
# Requesting URL: https://www.cardekho.com/used-Toyota+cars+in+bangalore
# Scrolling document upto bottom ...
# Closing Chrome ...
# row numbers:Toyota 56
# row_total 147
# Requesting URL: https://www.cardekho.com/used-Skoda+cars+in+bangalore
# Scrolling document upto bottom ...
# Closing Chrome ...
# row numbers:Skoda 60
# row_total 207
# Requesting URL: https://www.cardekho.com/used-Maruti+cars+in+bangalore
# Scrolling document upto bottom ...
# Closing Chrome ...
# row numbers:Maruti 58
# row_total 265
# Requesting URL: https://www.cardekho.com/used-hyundai+cars+in+bangalore
# Scrolling document upto bottom ...
# Closing Chrome ...
# ...

# %%
data=pd.DataFrame(final,columns=['model','brand','price','sold_year','seller','km_driven','owner_type','fuel','gear','mileage','engine','power','torque','wheel_size','seats','_','_',"_"])

# %%
data.to_csv("bangalore_cardekho.csv",sep=',')

# %%
pd.DataFrame(final)
# Out:
#                                                  0         1            2   \
# 0                        2015Mahindra XUV500 W8 2WD  Mahindra  10.58 Lakh*
# 1                        2015Mahindra XUV500 W8 2WD  Mahindra    9.5 Lakh*
# 2                        2014Mahindra XUV500 W8 2WD  Mahindra    9.5 Lakh*
# 3                           2016Mahindra TUV 300 T6  Mahindra      7 Lakh*
# 4                 2013Mahindra Bolero 2011-2019 ZLX  Mahindra   5.75 Lakh*
# 5                             2019Mahindra Thar 4X4  Mahindra  10.25 Lakh*
# 6                    2016Mahindra XUV500 AT W10 AWD  Mahindra  15.45 Lakh*
# 7          2016Mahindra KUV 100 mFALCON D75 K8 5str  Mahindra   5.25 Lakh*
# 8              2017Mahindra XUV500 AT W6 1.99 mHawk  Mahindra  12.75 Lakh*
# 9                      2015Mahindra TUV 300 T6 Plus  Mahindra    5.9 Lakh*
# 10                    2011Mahindra Scorpio SLE BSIV  Mahindra   5.65 Lakh*
# ...

# %%
# Out:
# RangeIndex(start=0, stop=445, step=1)

# %%
len(data)
# Out:
# 445

# %%
name_url="https://www.cardekho.com/used-"+brand+"+cars+in+jaipur"
driver = webdriver.Chrome(executable_path="C:\\Users\\n\\.wdm\\drivers\\chromedriver\\win32\\85.0.4183.87\\chromedriver")
print ("Requesting URL: " + name_url)
driver.get(name_url) 
time.sleep(1)   # URL requested in browser.
elem = driver.find_element_by_tag_name("body")
print ("Scrolling document upto bottom ...")
no_of_pagedowns = 20
while no_of_pagedowns:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.2)
    no_of_pagedowns-=1
body = driver.find_element_by_tag_name("body").get_attribute("innerHTML")
print("Closing Chrome ...") # No more usage needed.
driver.quit()
soupbody=BeautifulSoup(body,'html.parser')
# Out:
# Requesting URL: https://www.cardekho.com/used-hyundai+cars+in+jaipur
# Scrolling document upto bottom ...
# Closing Chrome ...

# %%
listi=[]
href_container=soupbody.find_all('a',attrs={'href':re.compile("/used-car-details/used-")})
for i in range(len(href_container)):
    listi.append([str(href_container[i])])
    
links=[]
for i in range(len(listi)):
    links.append(re.search('/used-car-details/used(.+?).htm', listi[i][0]).group(1))    
    
print("row numbers:" ,len(listi))
# Out:
# row numbers: 60

# %%
total_data=[]
final=[]
for link in links:
    url="https://www.cardekho.com/used-car-details/used"+link+".htm"
    hdr = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.64 Safari/537.11',
         'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8',
         'Referer': 'https://cssspritegenerator.com',
         'Accept-Charset': 'ISO-8859-1,utf-8;q=0.7,*;q=0.3',
         'Accept-Encoding': 'none',
         'Accept-Language': 'en-US,en;q=0.8',
         'Connection': 'keep-alive'}
    page=urllib.request.Request(url,None,headers=hdr)
    response = urllib.request.urlopen(page)
    soupbody=BeautifulSoup(response,'html.parser')
    details=soupbody.find_all('div',{"class":"iconDetail"})
    name_container=soupbody.find_all('div',{"class":"vdp-head"})
    price_container=soupbody.find_all('span',{"class":"amount"})
    total_data.append(name_container[0].text)
    total_data.append(price_container[0].text)
    for i in range(len(details)):
        total_data.append(details[i].text)
    final.append(list(total_data))
    total_data.clear()

# %%
y[0].text
# Out:
# '2019Maruti Swift LXI'
